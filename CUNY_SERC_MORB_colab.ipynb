# %% [markdown]
# <a href="https://colab.research.google.com/github/CCNY-Earthchem-Projects/geochem-ds/blob/main/CUNY_SERC_MORB_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Module 1: Global Geochemistry of Mid-Ocean Ridge Basalts (MORB)

# %%
""" Created on February 19, 2023 // @author: Sarah Shi, converted Kent Ratajeski's SERC modules to Python and added content """

# %% [markdown]
# Geological processes at the mid-ocean ridges are responsible for the bulk of the Earth's heat loss and volcanic activity. The compositions of materials erupted at these locations, dominantly mid-ocean ridge basalts (MORBs), have profound implications for the inner workings of the Earth's mantle, the construction of oceanic crust, and global plate tectonics. In this exercise, students replicate a portion of a classic paper on MORB geochemistry [(Klein and Langmuir, 1987)](https://agupubs.onlinelibrary.wiley.com/doi/10.1029/JB092iB08p08089), but using a much larger global geochemical dataset downloaded from the PetDB database. Through a series of activities and questions, students are encouraged to think about the petrologic and geodynamic processes controlling the composition of Earth's most abundant volcanic rocks.

# %% [markdown]
# ## I. Introduction
#
# #### Exploring and sampling the world's mid-ocean ridges
#
# Since the mid-20th century, our knowledge of undersea volcanic activity has expanded considerably as portions of the Earth's seafloor have been systematically explored. Dedicated scientific research vessels have obtained thousands of samples of oceanic crust by dredging, drilling, and small submersibles. These samples have been cataloged, analyzed, stored in large archives, and the resulting data has been published widely in the geological literature, contributing to our knowledge of the composition and origin of the oceanic crust. A large amount of these data are now available in digital format from the Petrological Database of the Ocean Floor ([PetDB](https://search.earthchem.org/)), a web-based data management system for geochemical and petrological sample-based data funded by the National Science Foundation.
#
# #### Mid-ocean ridge basalts: the Earth's most voluminous volcanic rocks
#
# On a volumetric basis, basaltic lavas erupted under the ocean at mid-ocean ridges are the most important products of terrestrial volcanism. What we have learned from mid-ocean basalts (MORBs) has had tremendous implications for our understanding of large-scale geodynamic and tectonic processes operating within the Earth's core, mantle, and crust.
#
# When studying a group of related igneous rocks, an important issue to ascertain is the amount of compositional variation that characterizes the dataset. This is of particular importance for the study of MORB's. Are MORBs relatively uniform in composition, perhaps suggesting partial melting from uniform source materials in the mantle followed by uniform modification by magmatic processes? Alternatively, does the global MORB dataset exhibit significant compositional variation, perhaps suggesting important differences in source materials, melting conditions, or subsequent magmatic processes? A related issue is whether geochemical variation in the MORB dataset is a function of geographic location (e.g., position along the mid-ocean ridge system). This may have important implications for lateral variations in composition, temperature, or pressure within the Earth's mantle. Keep these larger issues in mind as you work through the following exercise.

# %% [markdown]
# ### II. Accessing global datasets with simple coding (or Excel).
#
# ### What am I looking at here? ###
# This is a Jupyter Notebook, a document in a web browser that you can edit, generate text, and run code (typically Python). You may have previously seen or used a Jupyter Notebook for courses such as UN3400: Computational Earth Science. In this particalur case, to help the code run smoothly, we are doing the processing in the cloud using a tool called Google Colab. This means that you should be able to access all of the packages required and execute the code independent of the details of the computer that you are using locally - all you need is access to an internet connection and a web browser.
#
#
# ### Online Big Data - Bathymetry and MORB compositions ###
# A key feature of modern earth and environmental sciences is that huge observational, experimental and thermodynamic datasets are now available. The IEDA2 data infrastructures hosts observational datasets with EarthChem and experimental and thermodynamic datasets with LEPR/TraceDs (Library of Experimental Phase Relations/Trace element Distribution experimental database). Tools like Python allow for increased interaction with these datasets. In this practical we will look at one MORB dataset, which you can find on [PetDB](https://ecl.earthchem.org/view.php?id=274). You can click on the links to understand the data sources.
#
#
# ### NumPy for simple maths, Pandas for data-tables, and GMT for mapping ###
# We will explore simple chemical relationships in the geochemical data using [Numpy](https://numpy.org/) to perform simple mathematical calculations and using [Pandas](https://pandas.pydata.org/) to read in data. We will additionally use the [Generic Mapping Tools (GMT)](https://www.generic-mapping-tools.org/) package, which is now available in Python, to produce maps and examine mid-ocean ridge bathmetry. GMT is widely used in the Earth and Marine Sciences.
#
# I'll put a couple of cells of code in below, which you should run, in order to import the correct packages and bathymetry data for use in the practical.

# %%
import numpy as np
import pandas as pd
# These next few lines starting with exclamation marks are for Python environment setup. It takes a few moments to run, but allows you to not need to locally install anything. 
# !pip install -q condacolab
import condacolab
condacolab.install()
# !mamba install pygmt
import pygmt
from matplotlib import pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from matplotlib import rc
rc('font',**{'size': 14})
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:31
# 🔁 Restarting kernel...
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (1.1.0) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['pygmt']
#
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.3s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.4s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.5s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.6s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.7s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.8s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.9s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.3s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.4s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.5s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.6s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.7s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.8s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.9s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.3s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.4s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.5s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.6s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.7s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.8s
# conda-forge/linux-64  ⣾
# conda-forge/noarch   100%[+] 2.9s
# conda-forge/linux-64  ⣾
# conda-forge/noarch   100%[+] 3.0s
# conda-forge/linux-64  ⣾  conda-forge/noarch
# [+] 3.1s
# conda-forge/linux-64  ⣾  [+] 3.2s
# conda-forge/linux-64  ⣾  [+] 3.3s
# conda-forge/linux-64  ⣾  [+] 3.4s
# conda-forge/linux-64  ⣾  [+] 3.5s
# conda-forge/linux-64  ⣾  [+] 3.6s
# conda-forge/linux-64  ⣾  [+] 3.7s
# conda-forge/linux-64  ⣾  [+] 3.8s
# conda-forge/linux-64  ⣾  [+] 3.9s
# conda-forge/linux-64  ⣾  [+] 4.0s
# conda-forge/linux-64  ⣾  [+] 4.1s
# conda-forge/linux-64  ⣾  [+] 4.2s
# conda-forge/linux-64  ⣾  [+] 4.3s
# conda-forge/linux-64  ⣾  [+] 4.4s
# conda-forge/linux-64  ⣾  [+] 4.5s
# conda-forge/linux-64  ⣾  [+] 4.6s
# conda-forge/linux-64  ⣾  [+] 4.7s
# conda-forge/linux-64  ⣾  [+] 4.8s
# conda-forge/linux-64  ⣾  [+] 4.9s
# conda-forge/linux-64  ⣾  [+] 5.0s
# conda-forge/linux-64  ⣾  [+] 5.1s
# conda-forge/linux-64  ⣾  [+] 5.2s
# conda-forge/linux-64  ⣾  [+] 5.3s
# conda-forge/linux-64  ⣾  [+] 5.4s
# conda-forge/linux-64  ⣾  [+] 5.5s
# conda-forge/linux-64  ⣾  [+] 5.6s
# conda-forge/linux-64  ⣾  [+] 5.7s
# conda-forge/linux-64  ⣾  [+] 5.8s
# conda-forge/linux-64  ⣾  [+] 5.9s
# conda-forge/linux-64  ⣾  [+] 6.0s
# conda-forge/linux-64  ⣾  [+] 6.1s
# conda-forge/linux-64  ⣾  [+] 6.2s
# conda-forge/linux-64  ⣾  [+] 6.3s
# conda-forge/linux-64  ⣾  [+] 6.4s
# conda-forge/linux-64  ⣾  [+] 6.5s
# conda-forge/linux-64  ⣾  [+] 6.6s
# conda-forge/linux-64  ⣾  [+] 6.7s
# conda-forge/linux-64  ⣾  [+] 6.8s
# conda-forge/linux-64  ⣾  [+] 6.9s
# conda-forge/linux-64  ⣾  [+] 7.0s
# conda-forge/linux-64  ⣾  [+] 7.1s
# conda-forge/linux-64  ⣾  [+] 7.2s
# conda-forge/linux-64  ⣾  [+] 7.3s
# conda-forge/linux-64  ⣾  [+] 7.4s
# conda-forge/linux-64 100%[+] 7.5s
# conda-forge/linux-64 100%[+] 7.6s
# conda-forge/linux-64 100%[+] 7.7s
# conda-forge/linux-64 100%[+] 7.8s
# conda-forge/linux-64 100%[+] 7.9s
# conda-forge/linux-64 100%[+] 8.0s
# conda-forge/linux-64 100%[+] 8.1s
# conda-forge/linux-64 100%[+] 8.2s
# conda-forge/linux-64 100%[+] 8.3s
# conda-forge/linux-64 100%[+] 8.4s
# conda-forge/linux-64 100%[+] 8.5s
# conda-forge/linux-64 100%[+] 8.6s
# conda-forge/linux-64
#
# Pinned packages:
#   - python 3.9.*
#   - python 3.9.*
#   - python_abi 3.9.* *cp39*
#   - cudatoolkit 11.8.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - pygmt
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                       Version  Build                   Channel                   Size
# ─────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + blosc                        1.21.3  hafa529b_0              conda-forge/linux-64      40kB
#   + boost-cpp                    1.78.0  h75c5d50_1              conda-forge/linux-64      18MB
#   + cairo                        1.16.0  ha61ee94_1014           conda-forge/linux-64       2MB
#   + cfitsio                       4.2.0  hd9d235c_0              conda-forge/linux-64     848kB
#   + cftime                        1.6.2  py39h2ae25f5_1          conda-forge/linux-64     255kB
#   + curl                         7.88.1  hdc1c0ab_0              conda-forge/linux-64      88kB
#   + dcw-gmt                       2.1.1  ha770c72_0              conda-forge/linux-64      22MB
#   + expat                         2.5.0  h27087fc_0              conda-forge/linux-64     194kB
#   + fftw                         3.3.10  nompi_hf0379b8_106      conda-forge/linux-64       2MB
#   + font-ttf-dejavu-sans-mono      2.37  hab24e00_0              conda-forge/noarch       397kB
#   + font-ttf-inconsolata          3.000  h77eed37_0              conda-forge/noarch        97kB
#   + font-ttf-source-code-pro      2.038  h77eed37_0              conda-forge/noarch       701kB
#   + font-ttf-ubuntu                0.83  hab24e00_0              conda-forge/noarch         2MB
#   + fontconfig                   2.14.2  h14ed4e7_0              conda-forge/linux-64     272kB
#   + fonts-conda-ecosystem             1  0                       conda-forge/noarch         4kB
#   + fonts-conda-forge                 1  0                       conda-forge/noarch         4kB
#   + freetype                     2.12.1  hca18f0e_1              conda-forge/linux-64     626kB
#   + freexl                        1.0.6  h166bdaf_1              conda-forge/linux-64      50kB
#   + gdal                          3.6.3  py39h6b82872_4          conda-forge/linux-64       1MB
#   + geos                         3.11.2  hcb278e6_0              conda-forge/linux-64       2MB
#   + geotiff                       1.7.1  h480ec47_8              conda-forge/linux-64     256kB
#   + gettext                      0.21.1  h27087fc_0              conda-forge/linux-64       4MB
#   + ghostscript                  9.54.0  h27087fc_2              conda-forge/linux-64      60MB
#   + giflib                        5.2.1  h0b41bf4_3              conda-forge/linux-64      77kB
#   + gmt                           6.4.0  h4733502_10             conda-forge/linux-64      33MB
#   + gshhg-gmt                     2.3.7  ha770c72_1003           conda-forge/linux-64      57MB
#   + hdf4                         4.2.15  h501b40f_6              conda-forge/linux-64     758kB
#   + hdf5                         1.14.0  nompi_hb72d44e_103      conda-forge/linux-64       4MB
#   + json-c                         0.16  hc379101_0              conda-forge/linux-64     281kB
#   + kealib                        1.5.0  he7a6254_1              conda-forge/linux-64     166kB
#   + lcms2                          2.15  haa2dc70_1              conda-forge/linux-64     242kB
#   + lerc                          4.0.0  h27087fc_0              conda-forge/linux-64     282kB
#   + libaec                        1.0.6  hcb278e6_1              conda-forge/linux-64      34kB
#   + libblas                       3.9.0  16_linux64_openblas     conda-forge/linux-64      13kB
#   + libcblas                      3.9.0  16_linux64_openblas     conda-forge/linux-64      13kB
#   + libdeflate                     1.17  h0b41bf4_0              conda-forge/linux-64      65kB
#   + libgdal                       3.6.3  hb875ca4_4              conda-forge/linux-64      10MB
#   + libgfortran-ng               12.2.0  h69a702a_19             conda-forge/linux-64      23kB
#   + libgfortran5                 12.2.0  h337968e_19             conda-forge/linux-64       2MB
#   + libglib                      2.74.1  h606061b_1              conda-forge/linux-64       3MB
#   + libjpeg-turbo               2.1.5.1  h0b41bf4_0              conda-forge/linux-64     491kB
#   + libkml                        1.3.0  h37653c0_1015           conda-forge/linux-64     625kB
#   + liblapack                     3.9.0  16_linux64_openblas     conda-forge/linux-64      13kB
#   + libnetcdf                     4.9.2  nompi_hf3f8848_102      conda-forge/linux-64     803kB
#   + libopenblas                  0.3.21  pthreads_h78a6416_3     conda-forge/linux-64      11MB
#   + libpng                       1.6.39  h753d276_0              conda-forge/linux-64     283kB
#   + libpq                          15.2  hb675445_0              conda-forge/linux-64       2MB
#   + librttopo                     1.1.0  h0d5128d_13             conda-forge/linux-64     234kB
#   + libspatialite                 5.0.1  h7d1ca68_25             conda-forge/linux-64       3MB
#   + libtiff                       4.5.0  hddfeb54_5              conda-forge/linux-64     407kB
#   + libwebp-base                  1.3.0  h0b41bf4_0              conda-forge/linux-64     357kB
#   + libxcb                         1.13  h7f98852_1004           conda-forge/linux-64     400kB
#   + libzip                        1.9.2  hc929e4a_1              conda-forge/linux-64      99kB
#   + netcdf4                       1.6.3  nompi_py39h369ccc5_102  conda-forge/linux-64     501kB
#   + nspr                           4.35  h27087fc_0              conda-forge/linux-64     227kB
#   + nss                            3.89  he45b914_0              conda-forge/linux-64       2MB
#   + numpy                        1.24.2  py39h7360e5f_0          conda-forge/linux-64       7MB
#   + openjpeg                      2.5.0  hfec8fc6_2              conda-forge/linux-64     352kB
#   + packaging                      23.0  pyhd8ed1ab_0            conda-forge/noarch        41kB
#   + pandas                        1.5.3  py39h2ad29b5_0          conda-forge/linux-64      12MB
#   + pcre                           8.45  h9c3ff4c_0              conda-forge/linux-64     259kB
#   + pcre2                         10.40  hc3806b6_0              conda-forge/linux-64       2MB
#   + pixman                       0.40.0  h36c2ea0_0              conda-forge/linux-64     643kB
#   + poppler                     23.03.0  hf052cbe_1              conda-forge/linux-64      16MB
#   + poppler-data                 0.4.12  hd8ed1ab_0              conda-forge/noarch         2MB
#   + postgresql                     15.2  h3248436_0              conda-forge/linux-64       5MB
#   + proj                          9.2.0  h8ffa02c_0              conda-forge/linux-64       3MB
#   + pthread-stubs                   0.4  h36c2ea0_1001           conda-forge/linux-64       6kB
#   + pygmt                         0.8.0  pyhd8ed1ab_0            conda-forge/noarch       218kB
#   + python-dateutil               2.8.2  pyhd8ed1ab_0            conda-forge/noarch       246kB
#   + pytz                       2022.7.1  pyhd8ed1ab_0            conda-forge/noarch       186kB
#   + six                          1.16.0  pyh6c4a22f_0            conda-forge/noarch        14kB
#   + snappy                       1.1.10  h9fff704_0              conda-forge/linux-64      39kB
#   + sqlite                       3.40.0  h4ff8645_0              conda-forge/linux-64     820kB
#   + tiledb                       2.13.2  hd532e3d_0              conda-forge/linux-64       5MB
#   + tzcode                        2022g  h166bdaf_0              conda-forge/linux-64      67kB
#   + xarray                     2023.2.0  pyhd8ed1ab_0            conda-forge/noarch       663kB
#   + xerces-c                      3.2.4  h55805fa_1              conda-forge/linux-64       2MB
#   + xorg-kbproto                  1.0.7  h7f98852_1002           conda-forge/linux-64      27kB
#   + xorg-libice                  1.0.10  h7f98852_0              conda-forge/linux-64      59kB
#   + xorg-libsm                    1.2.3  hd9c2040_1000           conda-forge/linux-64      26kB
#   + xorg-libx11                   1.8.4  h0b41bf4_0              conda-forge/linux-64     830kB
#   + xorg-libxau                   1.0.9  h7f98852_0              conda-forge/linux-64      13kB
#   + xorg-libxdmcp                 1.1.3  h7f98852_0              conda-forge/linux-64      19kB
#   + xorg-libxext                  1.3.4  h0b41bf4_2              conda-forge/linux-64      50kB
#   + xorg-libxrender              0.9.10  h7f98852_1003           conda-forge/linux-64      33kB
#   + xorg-renderproto             0.11.1  h7f98852_1002           conda-forge/linux-64      10kB
#   + xorg-xextproto                7.3.0  h0b41bf4_1003           conda-forge/linux-64      30kB
#   + xorg-xproto                  7.0.31  h7f98852_1007           conda-forge/linux-64      75kB
#   + zlib                         1.2.13  h166bdaf_4              conda-forge/linux-64      94kB
#
#   Upgrade:
# ─────────────────────────────────────────────────────────────────────────────────────────────────
#
#   - openssl                       3.0.8  h0b41bf4_0              conda-forge
#   + openssl                       3.1.0  h0b41bf4_0              conda-forge/linux-64       3MB
#
#   Summary:
#
#   Install: 90 packages
#   Upgrade: 1 packages
#
#   Total download: 312MB
#
# ─────────────────────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%[+] 0.1s
# Downloading  (5)   0%
# Extracting         0%[+] 0.2s
# Downloading  (5)   0%
# Extracting         0%[+] 0.3s
# Downloading  (5)   0%
# Extracting         0%zlib                                                94.1kB @ 285.6kB/s  0.3s
# pcre                                               259.4kB @ 745.8kB/s  0.3s
# libjpeg-turbo                                      490.5kB @   1.3MB/s  0.4s
# [+] 0.4s
# Downloading  (9)   1%
# Extracting   (3)  ⣾  openssl                                              2.6MB @   6.7MB/s  0.4s
# geos                                                 1.5MB @   3.8MB/s  0.4s
# libpng                                             282.6kB @ 713.6kB/s  0.1s
# nspr                                               226.8kB @ 571.5kB/s  0.1s
# giflib                                              77.4kB @ 187.5kB/s  0.0s
# libgfortran5                                         1.8MB @   4.0MB/s  0.1s
# xorg-renderproto                                     9.6kB @  19.8kB/s  0.1s
# [+] 0.5s
# Downloading  (5)   3%
# Extracting  (10)  ⣾  xorg-libxdmcp                                       19.1kB @  34.6kB/s  0.1s
# libzip                                              99.4kB @ 179.4kB/s  0.1s
# [+] 0.6s
# Downloading  (5)   7%
# Extracting  (12)  ⣾  freetype                                           625.7kB @ 995.6kB/s  0.1s
# libtiff                                            406.7kB @ 645.8kB/s  0.1s
# libkml                                             624.7kB @ 926.8kB/s  0.0s
# xorg-libsm                                          26.4kB @  39.1kB/s  0.0s
# [+] 0.7s
# Downloading  (5)  12%
# Extracting  (16)  ⣾  fontconfig                                         272.0kB @ 360.4kB/s  0.1s
# [+] 0.8s
# Downloading  (5)  16%
# Extracting  (17)  ⣾  [+] 0.9s
# Downloading  (5)  19%
# Extracting  (16)  ⣾  tiledb                                               5.1MB @   5.5MB/s  0.3s
# [+] 1.0s
# Downloading  (5)  23%
# Extracting  (17)  ⣾  hdf5                                                 3.6MB @   3.6MB/s  0.2s
# [+] 1.1s
# Downloading  (5)  27%
# Extracting  (17)  ⣾  libspatialite                                        3.4MB @   3.1MB/s  0.2s
# kealib                                             166.2kB @ 150.8kB/s  0.1s
# dcw-gmt                                             22.0MB @  19.2MB/s  0.8s
# libcblas                                            12.8kB @  10.9kB/s  0.1s
# liblapack                                           12.8kB @  10.9kB/s  0.1s
# [+] 1.2s
# Downloading  (5)  31%
# Extracting  (22)  ⣾  pytz                                               186.2kB @ 152.4kB/s  0.1s
# font-ttf-dejavu-sans-mono                          397.4kB @ 324.8kB/s  0.1s
# fonts-conda-ecosystem                                3.7kB @   2.9kB/s  0.1s
# [+] 1.3s
# Downloading  (5)  36%
# Extracting  (25)  ⣾  [+] 1.4s
# Downloading  (5)  37%
# Extracting  (25)  ⣾  font-ttf-ubuntu                                      2.0MB @   1.5MB/s  0.2s
# [+] 1.5s
# Downloading  (5)  40%
# Extracting  (26)  ⣾  expat                                              194.0kB @ 128.5kB/s  0.2s
# [+] 1.6s
# Downloading  (5)  43%
# Extracting  (26)  ⣾  [+] 1.7s
# Downloading  (6)  49%
# Extracting  (26)  ⣾  pcre2                                                2.4MB @   1.4MB/s  0.2s
# pandas                                              12.0MB @   7.0MB/s  0.5s
# libgdal                                             10.2MB @   5.8MB/s  0.5s
# sqlite                                             820.2kB @ 464.2kB/s  0.1s
# [+] 1.8s
# Downloading  (5)  52%
# Extracting  (29)  ⣾  tzcode                                              66.6kB @  35.1kB/s  0.1s
# [+] 1.9s
# Downloading  (5)  55%
# Extracting  (30)  ⣾  gettext                                              4.3MB @   2.2MB/s  0.3s
# xorg-kbproto                                        27.3kB @  13.9kB/s  0.1s
# [+] 2.0s
# Downloading  (5)  57%
# Extracting  (33)  ⣾  xorg-libxau                                         13.4kB @   6.6kB/s  0.1s
# [+] 2.1s
# Downloading  (5)  60%
# Extracting  (34)  ⣾  libpq                                                2.5MB @   1.2MB/s  0.1s
# libglib                                              3.3MB @   1.5MB/s  0.1s
# gshhg-gmt                                           57.3MB @  26.3MB/s  1.8s
# [+] 2.2s
# Downloading  (5)  67%
# Extracting  (36)  ⣾  ghostscript                                         59.8MB @  26.7MB/s  1.9s
# cfitsio                                            848.0kB @ 374.1kB/s  0.1s
# postgresql                                           5.1MB @   2.2MB/s  0.2s
# proj                                                 2.9MB @   1.3MB/s  0.1s
# boost-cpp                                           18.0MB @   7.8MB/s  0.5s
# [+] 2.3s
# Downloading  (5)  73%
# Extracting  (41)  ⣾  libblas                                             12.9kB @   5.6kB/s  0.0s
# libnetcdf                                          803.0kB @ 342.6kB/s  0.1s
# cftime                                             255.2kB @ 108.3kB/s  0.1s
# font-ttf-source-code-pro                           700.8kB @ 297.2kB/s  0.1s
# [+] 2.4s
# Downloading  (5)  75%
# Extracting  (45)  ⣾  xarray                                             663.4kB @ 267.6kB/s  0.1s
# pygmt                                              218.2kB @  87.7kB/s  0.1s
# [+] 2.5s
# Downloading  (6)  76%
# Extracting  (46)  ⣾  [+] 2.6s
# Downloading  (6)  77%
# Extracting  (47)  ⣾  json-c                                             281.4kB @ 112.8kB/s  0.3s
# [+] 2.7s
# Downloading  (5)  77%
# Extracting  (47)  ⣾  [+] 2.8s
# Downloading  (8)  78%
# Extracting  (48)  ⣾  snappy                                              38.9kB @  14.4kB/s  0.3s
# pixman                                             642.5kB @ 237.2kB/s  0.3s
# xorg-xextproto                                      30.3kB @  11.2kB/s  0.3s
# numpy                                                6.7MB @   2.4MB/s  0.5s
# hdf4                                               757.7kB @ 266.5kB/s  0.2s
# libgfortran-ng                                      22.9kB @   7.9kB/s  0.2s
# [+] 2.9s
# Downloading  (6)  80%
# Extracting  (53)  ⣾  nss                                                  2.0MB @ 678.2kB/s  0.2s
# [+] 3.0s
# Downloading  (5)  84%
# Extracting  (55)  ⣾  fftw                                                 2.2MB @ 736.7kB/s  0.1s
# xorg-libx11                                        829.9kB @ 280.6kB/s  0.1s
# [+] 3.1s
# Downloading  (5)  84%
# Extracting  (57)  ⣾  poppler-data                                         2.3MB @ 749.9kB/s  0.3s
# poppler                                             15.6MB @   5.0MB/s  0.9s
# lerc                                               281.8kB @  89.3kB/s  0.1s
# [+] 3.2s
# Downloading  (6)  87%
# Extracting  (59)  ⣾  xorg-libice                                         59.4kB @  18.6kB/s  0.1s
# xorg-xproto                                         74.9kB @  23.4kB/s  0.1s
# libaec                                              34.4kB @  10.7kB/s  0.1s
# libopenblas                                         10.6MB @   3.3MB/s  0.3s
# [+] 3.3s
# Downloading  (5)  90%
# Extracting  (63)  ⣾  [+] 3.4s
# Downloading  (5)  91%
# Extracting  (63)  ⣾  openjpeg                                           352.0kB @ 105.9kB/s  0.3s
# geotiff                                            256.0kB @  76.7kB/s  0.3s
# netcdf4                                            501.1kB @ 148.5kB/s  0.2s
# packaging                                           40.7kB @  12.1kB/s  0.2s
# [+] 3.5s
# Downloading  (5)  91%
# Extracting  (67)  ⣾  [+] 3.6s
# Downloading  (8)  93%
# Extracting  (67)  ⣾  libdeflate                                          65.0kB @  18.3kB/s  0.1s
# libwebp-base                                       356.8kB @ 100.3kB/s  0.1s
# freexl                                              49.6kB @  13.9kB/s  0.1s
# xerces-c                                             1.8MB @ 506.6kB/s  0.2s
# six                                                 14.3kB @   3.9kB/s  0.1s
# font-ttf-inconsolata                                96.5kB @  26.7kB/s  0.1s
# python-dateutil                                    246.0kB @  67.9kB/s  0.1s
# pthread-stubs                                        5.6kB @   1.5kB/s  0.1s
# [+] 3.7s
# Downloading  (5)  94%
# Extracting  (75)  ⣾  curl                                                87.8kB @  23.7kB/s  0.1s
# librttopo                                          234.1kB @  63.1kB/s  0.1s
# blosc                                               40.3kB @  10.9kB/s  0.1s
# libxcb                                             399.9kB @ 107.7kB/s  0.1s
# fonts-conda-forge                                    4.1kB @   1.1kB/s  0.0s
# xorg-libxrender                                     32.9kB @   8.8kB/s  0.0s
# cairo                                                1.6MB @ 418.0kB/s  0.1s
# [+] 3.8s
# Downloading  (4)  97%
# Extracting  (82)  ⣾  gdal                                                 1.4MB @ 371.2kB/s  0.1s
# lcms2                                              242.1kB @  63.0kB/s  0.1s
# xorg-libxext                                        50.1kB @  13.1kB/s  0.1s
# [+] 3.9s
# Downloading  (1)  99%
# Extracting  (85)  ⣾  gmt                                                 32.5MB @   8.2MB/s  0.9s
# [+] 4.0s
# Downloading      100%
# Extracting  (86)  ⣾  [+] 4.1s
# Downloading      100%
# Extracting  (86)  ⣾  [+] 4.2s
# Downloading      100%
# Extracting  (86)  ⣾  [+] 4.3s
# Downloading      100%
# Extracting  (86)  ⣾  [+] 4.4s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 4.5s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 4.6s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 4.7s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 4.8s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 4.9s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 5.0s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 5.1s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 5.2s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 5.3s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 5.4s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 5.5s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 5.6s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 5.7s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 5.8s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 5.9s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 6.0s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 6.1s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 6.2s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 6.3s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 6.4s
# Downloading      100%
# Extracting  (84)  ⣾  [+] 6.5s
# Downloading      100%
# Extracting  (84)  ⣾  [+] 6.6s
# Downloading      100%
# Extracting  (84)  ⣾  [+] 6.7s
# Downloading      100%
# Extracting  (84)  ⣾  [+] 6.8s
# Downloading      100%
# Extracting  (84)  ⣾  [+] 6.9s
# Downloading      100%
# Extracting  (84)  ⣾  [+] 7.0s
# Downloading      100%
# Extracting  (84)  ⣾  [+] 7.1s
# Downloading      100%
# Extracting  (83)  ⣾  [+] 7.2s
# Downloading      100%
# Extracting  (83)  ⣾  [+] 7.3s
# Downloading      100%
# Extracting  (83)  ⣾  [+] 7.4s
# Downloading      100%
# Extracting  (83)  ⣾  [+] 7.5s
# Downloading      100%
# Extracting  (83)  ⣾  [+] 7.6s
# Downloading      100%
# Extracting  (83)  ⣾  [+] 7.7s
# Downloading      100%
# Extracting  (83)  ⣾  [+] 7.8s
# Downloading      100%
# Extracting  (83)  ⣾  [+] 7.9s
# Downloading      100%
# Extracting  (83)  ⣾  [+] 8.0s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 8.1s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 8.2s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 8.3s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 8.4s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 8.5s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 8.6s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 8.7s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 8.8s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 8.9s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 9.0s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 9.1s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 9.2s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 9.3s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 9.4s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 9.5s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 9.6s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 9.7s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 9.8s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 9.9s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 10.0s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 10.1s
# Downloading      100%
# Extracting  (81)  ⣾  [+] 10.2s
# Downloading      100%
# Extracting  (81)  ⣾  [+] 10.3s
# Downloading      100%
# Extracting  (81)  ⣾  [+] 10.4s
# Downloading      100%
# Extracting  (81)  ⣾  [+] 10.5s
# Downloading      100%
# Extracting  (81)  ⣾  [+] 10.6s
# Downloading      100%
# Extracting  (81)  ⣾  [+] 10.7s
# Downloading      100%
# Extracting  (80)  ⣾  [+] 10.8s
# Downloading      100%
# Extracting  (80)  ⣾  [+] 10.9s
# Downloading      100%
# Extracting  (80)  ⣾  [+] 11.0s
# Downloading      100%
# Extracting  (80)  ⣾  [+] 11.1s
# Downloading      100%
# Extracting  (80)  ⣾  [+] 11.2s
# Downloading      100%
# Extracting  (80)  ⣾  [+] 11.3s
# Downloading      100%
# Extracting  (80)  ⣾  [+] 11.4s
# Downloading      100%
# Extracting  (80)  ⣾  [+] 11.5s
# Downloading      100%
# Extracting  (80)  ⣾  [+] 11.6s
# Downloading      100%
# Extracting  (80)  ⣾  [+] 11.7s
# Downloading      100%
# Extracting  (79)  ⣾  [+] 11.8s
# Downloading      100%
# Extracting  (79)  ⣾  [+] 11.9s
# Downloading      100%
# Extracting  (79)  ⣾  [+] 12.0s
# Downloading      100%
# Extracting  (79)  ⣾  [+] 12.1s
# Downloading      100%
# Extracting  (79)  ⣾  [+] 12.2s
# Downloading      100%
# Extracting  (78)  ⣾  [+] 12.3s
# Downloading      100%
# Extracting  (78)  ⣾  [+] 12.4s
# Downloading      100%
# Extracting  (78)  ⣾  [+] 12.5s
# Downloading      100%
# Extracting  (77)  ⣾  [+] 12.6s
# Downloading      100%
# Extracting  (77)  ⣾  [+] 12.7s
# Downloading      100%
# Extracting  (77)  ⣾  [+] 12.8s
# Downloading      100%
# Extracting  (77)  ⣾  [+] 12.9s
# Downloading      100%
# Extracting  (76)  ⣾  [+] 13.0s
# Downloading      100%
# Extracting  (76)  ⣾  [+] 13.1s
# Downloading      100%
# Extracting  (75)  ⣾  [+] 13.2s
# Downloading      100%
# Extracting  (75)  ⣾  [+] 13.3s
# Downloading      100%
# Extracting  (74)  ⣾  [+] 13.4s
# Downloading      100%
# Extracting  (74)  ⣾  [+] 13.5s
# Downloading      100%
# Extracting  (74)  ⣾  [+] 13.6s
# Downloading      100%
# Extracting  (73)  ⣾  [+] 13.7s
# Downloading      100%
# Extracting  (73)  ⣾  [+] 13.8s
# Downloading      100%
# Extracting  (73)  ⣾  [+] 13.9s
# Downloading      100%
# Extracting  (73)  ⣾  [+] 14.0s
# Downloading      100%
# Extracting  (73)  ⣾  [+] 14.1s
# Downloading      100%
# Extracting  (73)  ⣾  [+] 14.2s
# Downloading      100%
# Extracting  (73)  ⣾  [+] 14.3s
# Downloading      100%
# Extracting  (73)  ⣾  [+] 14.4s
# Downloading      100%
# Extracting  (72)  ⣾  [+] 14.5s
# Downloading      100%
# Extracting  (72)  ⣾  [+] 14.6s
# Downloading      100%
# Extracting  (72)  ⣾  [+] 14.7s
# Downloading      100%
# Extracting  (72)  ⣾  [+] 14.8s
# Downloading      100%
# Extracting  (72)  ⣾  [+] 14.9s
# Downloading      100%
# Extracting  (72)  ⣾  [+] 15.0s
# Downloading      100%
# Extracting  (72)  ⣾  [+] 15.1s
# Downloading      100%
# Extracting  (72)  ⣾  [+] 15.2s
# Downloading      100%
# Extracting  (71)  ⣾  [+] 15.3s
# Downloading      100%
# Extracting  (71)  ⣾  [+] 15.4s
# Downloading      100%
# Extracting  (71)  ⣾  [+] 15.5s
# Downloading      100%
# Extracting  (70)  ⣾  [+] 15.6s
# Downloading      100%
# Extracting  (70)  ⣾  [+] 15.7s
# Downloading      100%
# Extracting  (70)  ⣾  [+] 15.8s
# Downloading      100%
# Extracting  (70)  ⣾  [+] 15.9s
# Downloading      100%
# Extracting  (69)  ⣾  [+] 16.0s
# Downloading      100%
# Extracting  (69)  ⣾  [+] 16.1s
# Downloading      100%
# Extracting  (69)  ⣾  [+] 16.2s
# Downloading      100%
# Extracting  (69)  ⣾  [+] 16.3s
# Downloading      100%
# Extracting  (69)  ⣾  [+] 16.4s
# Downloading      100%
# Extracting  (68)  ⣾  [+] 16.5s
# Downloading      100%
# Extracting  (68)  ⣾  [+] 16.6s
# Downloading      100%
# Extracting  (68)  ⣾  [+] 16.7s
# Downloading      100%
# Extracting  (68)  ⣾  [+] 16.8s
# Downloading      100%
# Extracting  (67)  ⣾  [+] 16.9s
# Downloading      100%
# Extracting  (67)  ⣾  [+] 17.0s
# Downloading      100%
# Extracting  (67)  ⣾  [+] 17.1s
# Downloading      100%
# Extracting  (67)  ⣾  [+] 17.2s
# Downloading      100%
# Extracting  (66)  ⣾  [+] 17.3s
# Downloading      100%
# Extracting  (66)  ⣾  [+] 17.4s
# Downloading      100%
# Extracting  (66)  ⣾  [+] 17.5s
# Downloading      100%
# Extracting  (66)  ⣾  [+] 17.6s
# Downloading      100%
# Extracting  (65)  ⣾  [+] 17.7s
# Downloading      100%
# Extracting  (65)  ⣾  [+] 17.8s
# Downloading      100%
# Extracting  (65)  ⣾  [+] 17.9s
# Downloading      100%
# Extracting  (64)  ⣾  [+] 18.0s
# Downloading      100%
# Extracting  (64)  ⣾  [+] 18.1s
# Downloading      100%
# Extracting  (64)  ⣾  [+] 18.2s
# Downloading      100%
# Extracting  (64)  ⣾  [+] 18.3s
# Downloading      100%
# Extracting  (64)  ⣾  [+] 18.4s
# Downloading      100%
# Extracting  (63)  ⣾  [+] 18.5s
# Downloading      100%
# Extracting  (63)  ⣾  [+] 18.6s
# Downloading      100%
# Extracting  (63)  ⣾  [+] 18.7s
# Downloading      100%
# Extracting  (63)  ⣾  [+] 18.8s
# Downloading      100%
# Extracting  (62)  ⣾  [+] 18.9s
# Downloading      100%
# Extracting  (62)  ⣾  [+] 19.0s
# Downloading      100%
# Extracting  (62)  ⣾  [+] 19.1s
# Downloading      100%
# Extracting  (61)  ⣾  [+] 19.2s
# Downloading      100%
# Extracting  (61)  ⣾  [+] 19.3s
# Downloading      100%
# Extracting  (61)  ⣾  [+] 19.4s
# Downloading      100%
# Extracting  (60)  ⣾  [+] 19.5s
# Downloading      100%
# Extracting  (60)  ⣾  [+] 19.6s
# Downloading      100%
# Extracting  (60)  ⣾  [+] 19.7s
# Downloading      100%
# Extracting  (60)  ⣾  [+] 19.8s
# Downloading      100%
# Extracting  (59)  ⣾  [+] 19.9s
# Downloading      100%
# Extracting  (59)  ⣾  [+] 20.0s
# Downloading      100%
# Extracting  (59)  ⣾  [+] 20.1s
# Downloading      100%
# Extracting  (59)  ⣾  [+] 20.2s
# Downloading      100%
# Extracting  (58)  ⣾  [+] 20.3s
# Downloading      100%
# Extracting  (58)  ⣾  [+] 20.4s
# Downloading      100%
# Extracting  (58)  ⣾  [+] 20.5s
# Downloading      100%
# Extracting  (57)  ⣾  [+] 20.6s
# Downloading      100%
# Extracting  (57)  ⣾  [+] 20.7s
# Downloading      100%
# Extracting  (57)  ⣾  [+] 20.8s
# Downloading      100%
# Extracting  (57)  ⣾  [+] 20.9s
# Downloading      100%
# Extracting  (57)  ⣾  [+] 21.0s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 21.1s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 21.2s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 21.3s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 21.4s
# Downloading      100%
# Extracting  (55)  ⣾  [+] 21.5s
# Downloading      100%
# Extracting  (55)  ⣾  [+] 21.6s
# Downloading      100%
# Extracting  (55)  ⣾  [+] 21.7s
# Downloading      100%
# Extracting  (55)  ⣾  [+] 21.8s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 21.9s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 22.0s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 22.1s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 22.2s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 22.3s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 22.4s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 22.5s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 22.6s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 22.7s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 22.8s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 22.9s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 23.0s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 23.1s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 23.2s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 23.3s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 23.4s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 23.5s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 23.6s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 23.7s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 23.8s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 23.9s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 24.0s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 24.1s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 24.2s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 24.3s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 24.4s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 24.5s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 24.6s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 24.7s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 24.8s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 24.9s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 25.0s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 25.1s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 25.2s
# Downloading      100%
# Extracting  (51)  ⣾  [+] 25.3s
# Downloading      100%
# Extracting  (51)  ⣾  [+] 25.4s
# Downloading      100%
# Extracting  (51)  ⣾  [+] 25.5s
# Downloading      100%
# Extracting  (51)  ⣾  [+] 25.6s
# Downloading      100%
# Extracting  (51)  ⣾  [+] 25.7s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 25.8s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 25.9s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 26.0s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 26.1s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 26.2s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 26.3s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 26.4s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 26.5s
# Downloading      100%
# Extracting  (49)  ⣾  [+] 26.6s
# Downloading      100%
# Extracting  (49)  ⣾  [+] 26.7s
# Downloading      100%
# Extracting  (49)  ⣾  [+] 26.8s
# Downloading      100%
# Extracting  (49)  ⣾  [+] 26.9s
# Downloading      100%
# Extracting  (49)  ⣾  [+] 27.0s
# Downloading      100%
# Extracting  (49)  ⣾  [+] 27.1s
# Downloading      100%
# Extracting  (49)  ⣾  [+] 27.2s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 27.3s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 27.4s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 27.5s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 27.6s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 27.7s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 27.8s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 27.9s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 28.0s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 28.1s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 28.2s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 28.3s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 28.4s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 28.5s
# Downloading      100%
# Extracting  (47)  ⣾  [+] 28.6s
# Downloading      100%
# Extracting  (47)  ⣾  [+] 28.7s
# Downloading      100%
# Extracting  (47)  ⣾  [+] 28.8s
# Downloading      100%
# Extracting  (47)  ⣾  [+] 28.9s
# Downloading      100%
# Extracting  (47)  ⣾  [+] 29.0s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 29.1s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 29.2s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 29.3s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 29.4s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 29.5s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 29.6s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 29.7s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 29.8s
# Downloading      100%
# Extracting  (45)  ⣾  [+] 29.9s
# Downloading      100%
# Extracting  (45)  ⣾  [+] 30.0s
# Downloading      100%
# Extracting  (45)  ⣾  [+] 30.1s
# Downloading      100%
# Extracting  (45)  ⣾  [+] 30.2s
# Downloading      100%
# Extracting  (45)  ⣾  [+] 30.3s
# Downloading      100%
# Extracting  (45)  ⣾  [+] 30.4s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 30.5s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 30.6s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 30.7s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 30.8s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 30.9s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 31.0s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 31.1s
# Downloading      100%
# Extracting  (43)  ⣾  [+] 31.2s
# Downloading      100%
# Extracting  (42)  ⣾  [+] 31.3s
# Downloading      100%
# Extracting  (42)  ⣾  [+] 31.4s
# Downloading      100%
# Extracting  (42)  ⣾  [+] 31.5s
# Downloading      100%
# Extracting  (42)  ⣾  [+] 31.6s
# Downloading      100%
# Extracting  (42)  ⣾  [+] 31.7s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 31.8s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 31.9s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 32.0s
# Downloading      100%
# Extracting  (40)  ⣾  [+] 32.1s
# Downloading      100%
# Extracting  (40)  ⣾  [+] 32.2s
# Downloading      100%
# Extracting  (40)  ⣾  [+] 32.3s
# Downloading      100%
# Extracting  (38)  ⣾  [+] 32.4s
# Downloading      100%
# Extracting  (38)  ⣾  [+] 32.5s
# Downloading      100%
# Extracting  (38)  ⣾  [+] 32.6s
# Downloading      100%
# Extracting  (38)  ⣾  [+] 32.7s
# Downloading      100%
# Extracting  (37)  ⣾  [+] 32.8s
# Downloading      100%
# Extracting  (37)  ⣾  [+] 32.9s
# Downloading      100%
# Extracting  (36)  ⣾  [+] 33.0s
# Downloading      100%
# Extracting  (36)  ⣾  [+] 33.1s
# Downloading      100%
# Extracting  (36)  ⣾  [+] 33.2s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 33.3s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 33.4s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 33.5s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 33.6s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 33.7s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 33.8s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 33.9s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 34.0s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 34.1s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 34.2s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 34.3s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 34.4s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 34.5s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 34.6s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 34.7s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 34.8s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 34.9s
# Downloading      100%
# Extracting  (31)  ⣾  [+] 35.0s
# Downloading      100%
# Extracting  (31)  ⣾  [+] 35.1s
# Downloading      100%
# Extracting  (31)  ⣾  [+] 35.2s
# Downloading      100%
# Extracting  (31)  ⣾  [+] 35.3s
# Downloading      100%
# Extracting  (31)  ⣾  [+] 35.4s
# Downloading      100%
# Extracting  (31)  ⣾  [+] 35.5s
# Downloading      100%
# Extracting  (29)  ⣾  [+] 35.6s
# Downloading      100%
# Extracting  (29)  ⣾  [+] 35.7s
# Downloading      100%
# Extracting  (29)  ⣾  [+] 35.8s
# Downloading      100%
# Extracting  (29)  ⣾  [+] 35.9s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 36.0s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 36.1s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 36.2s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 36.3s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 36.4s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 36.5s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 36.6s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 36.7s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 36.8s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 36.9s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 37.0s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 37.1s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 37.2s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 37.3s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 37.4s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 37.5s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 37.6s
# Downloading      100%
# Extracting  (26)  ⣾  [+] 37.7s
# Downloading      100%
# Extracting  (26)  ⣾  [+] 37.8s
# Downloading      100%
# Extracting  (26)  ⣾  [+] 37.9s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 38.0s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 38.1s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 38.2s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 38.3s
# Downloading      100%
# Extracting  (24)  ⣾  [+] 38.4s
# Downloading      100%
# Extracting  (24)  ⣾  [+] 38.5s
# Downloading      100%
# Extracting  (24)  ⣾  [+] 38.6s
# Downloading      100%
# Extracting  (24)  ⣾  [+] 38.7s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 38.8s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 38.9s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 39.0s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 39.1s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 39.2s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 39.3s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 39.4s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 39.5s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 39.6s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 39.7s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 39.8s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 39.9s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 40.0s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 40.1s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 40.2s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 40.3s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 40.4s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 40.5s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 40.6s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 40.7s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 40.8s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 40.9s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 41.0s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 41.1s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 41.2s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 41.3s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 41.4s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 41.5s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 41.6s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 41.7s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 41.8s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 41.9s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 42.0s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 42.1s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 42.2s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 42.3s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 42.4s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 42.5s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 42.6s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 42.7s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 42.8s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 42.9s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 43.0s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 43.1s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 43.2s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 43.3s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 43.4s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 43.5s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 43.6s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 43.7s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 43.8s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 43.9s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 44.0s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 44.1s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 44.2s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 44.3s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 44.4s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 44.5s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 44.6s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 44.7s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 44.8s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 44.9s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 45.0s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 45.1s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 45.2s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 45.3s
# Downloading      100%
# Extracting  (20)  ⣾  [+] 45.4s
# Downloading      100%
# Extracting  (20)  ⣾  [+] 45.5s
# Downloading      100%
# Extracting  (20)  ⣾  [+] 45.6s
# Downloading      100%
# Extracting  (20)  ⣾  [+] 45.7s
# Downloading      100%
# Extracting  (20)  ⣾  [+] 45.8s
# Downloading      100%
# Extracting  (20)  ⣾  [+] 45.9s
# Downloading      100%
# Extracting  (20)  ⣾  [+] 46.0s
# Downloading      100%
# Extracting  (19)  ⣾  [+] 46.1s
# Downloading      100%
# Extracting  (19)  ⣾  [+] 46.2s
# Downloading      100%
# Extracting  (19)  ⣾  [+] 46.3s
# Downloading      100%
# Extracting  (19)  ⣾  [+] 46.4s
# Downloading      100%
# Extracting  (19)  ⣾  [+] 46.5s
# Downloading      100%
# Extracting  (19)  ⣾  [+] 46.6s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 46.7s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 46.8s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 46.9s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 47.0s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 47.1s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 47.2s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 47.3s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 47.4s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 47.5s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 47.6s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 47.7s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 47.8s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 47.9s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 48.0s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 48.1s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 48.2s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 48.3s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 48.4s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 48.5s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 48.6s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 48.7s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 48.8s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 48.9s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 49.0s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 49.1s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 49.2s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 49.3s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 49.4s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 49.5s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 49.6s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 49.7s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 49.8s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 49.9s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 50.0s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 50.1s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 50.2s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 50.3s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 50.4s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 50.5s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 50.6s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 50.7s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 50.8s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 50.9s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 51.0s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 51.1s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 51.2s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 51.3s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 51.4s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 51.5s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 51.6s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 51.7s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 51.8s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 51.9s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 52.0s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 52.1s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 52.2s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 52.3s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 52.4s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 52.5s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 52.6s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 52.7s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 52.8s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 52.9s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 53.0s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 53.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 53.2s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 53.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 53.4s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 53.5s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 53.6s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 53.7s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 53.8s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 53.9s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 54.0s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 54.1s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 54.2s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 54.3s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 54.4s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 54.5s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 54.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 54.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 54.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 54.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 55.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 55.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:4.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:4.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:4.2s
# Downloading      100%
# Extracting       100%
# Downloading and Extracting Packages
#
# done
# done
# done
# ---------------------------------------------------------------------------
# GMTCLibNotFoundError                      Traceback (most recent call last)
# <ipython-input-1-9b6890099622> in <module>
#       6 condacolab.install()
#       7 get_ipython().system('mamba install pygmt')
# ----> 8 import pygmt
#       9 from matplotlib import pyplot as plt
#      10 get_ipython().run_line_magic('matplotlib', 'inline')
#
# /usr/local/lib/python3.9/site-packages/pygmt/__init__.py in <module>
#      72
#      73 # Start our global modern mode session
# ---> 74 _begin()
#      75 # Tell Python to run _end when shutting down
#      76 _atexit.register(_end)
#
# /usr/local/lib/python3.9/site-packages/pygmt/session_management.py in begin()
#      14     """
#      15     prefix = "pygmt-session"
# ---> 16     with Session() as lib:
#      17         lib.call_module(module="begin", args=prefix)
#      18         # pygmt relies on GMT modern mode with GMT_COMPATIBILITY at version 6
#
# /usr/local/lib/python3.9/site-packages/pygmt/clib/session.py in __enter__(self)
#     189             raising the exception.
#     190         """
# --> 191         self.create("pygmt-session")
#     192         # Need to store the version info because 'get_default' won't work after
#     193         # the session is destroyed.
#
# /usr/local/lib/python3.9/site-packages/pygmt/clib/session.py in create(self, name)
#     336             pass
#     337
# --> 338         c_create_session = self.get_libgmt_func(
#     339             "GMT_Create_Session",
#     340             argtypes=[ctp.c_char_p, ctp.c_uint, ctp.c_uint, ctp.c_void_p],
#
# /usr/local/lib/python3.9/site-packages/pygmt/clib/session.py in get_libgmt_func(self, name, argtypes, restype)
#     288         if not hasattr(self, "_libgmt"):
#     289             # pylint: disable=attribute-defined-outside-init
# --> 290             self._libgmt = load_libgmt()
#     291         function = getattr(self._libgmt, name)
#     292         if argtypes is not None:
#
# /usr/local/lib/python3.9/site-packages/pygmt/clib/loading.py in load_libgmt(lib_fullnames)
#      57
#      58     if error:
# ---> 59         raise GMTCLibNotFoundError("\n".join(error_msg))
#      60
#      61     return libgmt
#
# GMTCLibNotFoundError: Error loading GMT shared library at '/usr/local/lib/libgmt.so'.
# /lib/x86_64-linux-gnu/libstdc++.so.6: version `GLIBCXX_3.4.30' not found (required by /usr/local/lib/./libgdal.so.32)
# Error loading GMT shared library at 'libgmt.so'.
# libgmt.so: cannot open shared object file: No such file or directory

# %% [markdown]
# ### III. Analyze the data.
#
# ##### 1. Open the file you have just downloaded in Excel. Notice the huge amount of data! This is only a subset of the MORB samples available on PetDB. Those marine geologists have definitely been busy!

# %%
# Read in the datasets here with the Pandas package. We are storing the data as a dataframe, which is a 2D labeled data structure, like a 2D array or table with rows and columns. 

df = pd.read_csv("https://raw.githubusercontent.com/sarahshi/earthchem-teaching/main/ClassandLehnertMORB.csv")

# %%
# Visualize the dataset by calling the first 5 rows of data. What information is available?

df.head()

# %%
# We can print all column names to understand what is available by calling: 

df.columns

# %% [markdown]
# You can access particular columns of data by referencing them in two ways as follows:

# %%
df['SiO2']

# %%
df.SiO2

# %% [markdown]
# Note the presence of NaN values. These are simply blank values in the Excel file.

# %% [markdown]
# ##### 2. Now you'll make a series of plots of the consolidated global data. Start by making an x-y plot of longitude (on the x-axis) vs. latitude (on the y-axis). Does the resulting graph look familiar?

# %%
# I will walk through a PyGMT figure plotting example below. There are plotting particularities that you do not need to worry about. 
# Focus on the fig.plot portion of plotting code, where plotting the scatter points happens. Make sure you understand what is being plotted there. 

grid = pygmt.datasets.load_earth_relief() # loads earth relief
fig = pygmt.Figure() # defines a figure
fig.subplot(nrows = 1, ncols = 1, figsize = ('20c', '15c')) # defines a plot with size
# Plot the earth relief grid on Cylindrical Stereographic projection, masking
fig.basemap(region="g", projection="Cyl_stere/0/-20/15c", frame=True) # creates the base projection map
fig.grdimage(grid=grid, cmap="gray", transparency=40,) # sets the background depiction of bathymetry
fig.coast(land="#666666") # creates continents 

pygmt.makecpt(cmap="viridis", series=[df.Elevation.min(), df.Elevation.max()]) # defines a colormap with color ranging from minimum to maximum bathymetric elevation 
fig.plot(x=df.Longitude, y=df.Latitude, style="c0.25c", # plot x and y, with color of scatter points showing bathymetric elevation 
    color=df.Elevation,
    cmap=True, pen='black', transparency=40,)
fig.colorbar(frame='af+l"Axial Depth (m)"') # create colorbar 
fig.show()

# %% [markdown]
# ##### A. Can you identify the Mid-Atlantic Ridge and the East Pacific Rise on your graph? Provide a range of longitudes/latitudes. These are two of the best studied mid-ocean ridges.

# %% [markdown]
# Answer here:

# %% [markdown]
# ##### B. What is plotted on the x-axis and y-axis? What do the colors of the scatter points represent?

# %% [markdown]
# Answer here:

# %% [markdown]
# ##### 3. Let's visualize $SiO_2$ (y-axis) vs. $MgO$ (x-axis), and $FeO$ (y-axis) vs. $MgO$ (x-axis). We can do so quite easily by using the matplotlib package, which we imported at the start. I show below how you plot $SiO_2$ vs. $MgO$, as an example.

# %%
plt.figure(figsize=(6, 4)) # define figure and figure size, width vs. height
plt.scatter(df.MgO, df.SiO2, edgecolor='k', linewidth = 0.5, alpha=0.75) # scatter (x, y), edgecolor and linewidth define the scatter outlines, alpha defines transparency. 
plt.xlabel('MgO (wt.%)') # label x-axis
plt.ylabel('SiO2 (wt.%)') # label y-axis
plt.xlim([4, 12]) # set x-axis range
plt.ylim([46, 56]) # set y-axis range. 
plt.show()

# %% [markdown]
# ##### A. Please make the corresponding plot for $FeO$ vs. $MgO$.

# %%
# Make the plot for FeO vs. MgO

# %% [markdown]
# ##### B. According to your plot and ignoring outlying samples, what is the range in $SiO_2$ of the main cluster of MORB glasses? Is this variation real?--i.e., is it greater than the ~1 wt.% error for $SiO_2$ in volcanic glasses?

# %% [markdown]
# Answer here:

# %% [markdown]
# ##### C. Ignoring outlying samples, what seems to be the range of MgO for the global MORB dataset? Is this variation real?--i.e., is it above or below the ~0.5 wt.% error for $MgO$ analysis in volcanic glasses?

# %% [markdown]
# Answer here:

# %% [markdown]
# ##### D. What is the range in $FeO$, and is the variation real if there is a 0.5 wt.% error for $FeO$ in volcanic glasses?

# %% [markdown]
# Answer here:

# %% [markdown]
# ##### D. What is the most likely cause for most of the geochemical variation in $MgO$ and $SiO_2$? (Hint: think of processes involving low-$Si$ and high-$Mg$ solids.)

# %% [markdown]
# Answer here:

# %% [markdown]
# ##### E. In terms of $MgO$ content, which glass compositions will be more closely related to their original mantle sources?--low $MgO$, medium $MgO$, or high $MgO$?

# %% [markdown]
# Answer here:

# %% [markdown]
# ##### F. For the keen beans in the class, learn how to plot $SiO_2$ (y-axis) vs. $MgO$ (x-axis), and $FeO$ (y-axis) vs. $MgO$ (x-axis) but now with the scatter points colored by axial depth.

# %%
# Plot SiO2 (y-axis) vs. MgO (x-axis), and FeO (y-axis) vs. MgO (x-axis) but now with the scatter points colored by axial depth.

# %% [markdown]
# ##### 4. It will be of interest now to focus on the geochemical variation among the more primitive MORB liquids, but to do this, we need to find a way to correct for the effects of fractionation. Well, we're in luck! A method of fractionation correction has been developed by [(Klein and Langmuir, 1987)](https://agupubs.onlinelibrary.wiley.com/doi/10.1029/JB092iB08p08089) which is based on the observation that low-pressure fractionation of a primitive basaltic liquid within an individual volcanic suite (or at a specific location) results in a more-or-less linear array ("liquid lines of descent") on major-element variation diagrams, at least over certain ranges of MgO. Because their fractionating mineral assemblages are similar, the slopes of these liquid lines of descent for different igneous suites (or locations) are more or less sub-parallel to one another. If the slope of these linear variation arrays is known, and they are, it should be feasible to determine "calculated" values of a particular element-oxide (from different suites or locations) at a constant value of $MgO$. We are thus able to compare the variation in $Na$, rather than the variation due to varying melt proportions. To approximate a fairly primitive basaltic liquid composition, a value of $MgO$ = 8 wt.% is arbitrarily chosen for the value at which the "calculated" element-oxides are compared. You will perform this correction now.

# %% [markdown]
# Create additional dataframe columns to define the following variables:
#
# $\frac{CaO}{Al_2O_3} = \frac{CaO (wt.\%)}{Al_2O_3 (wt.\%)}$
#
# $Na_{8.0} = Na_2O + 0.373*MgO - 2.98$
#
# The equation for $Na_{8.0}$ is from [(Klein and Langmuir, 1987)](https://agupubs.onlinelibrary.wiley.com/doi/10.1029/JB092iB08p08089). $\frac{CaO}{Al_2O_3}$ does not change much with fractionation, so does not need to be corrected. I show below how to create a new column for $\frac{CaO}{Al_2O_3}$ and for $Na_{8.0}$. There is a simplicity to the dataframe structure that allows you to apply the same mathematical operation to all rows.

# %%
# For simple mathematical operations, addition uses '+', subtraction uses'-', multiplication uses '*', division uses '/'. 

df['CaO_Al2O3'] = df['CaO'] / df['Al2O3'] # I create the new column of the dataframe called 'CaO_Al2O3' by placing that variable in square braces, then define how to perform division. 
df['CaO_Al2O3']

# %%
# Calculate $Na_{8.0}$ here. 

df['Na8'] = df['Na2O'] + 0.373*df['MgO'] - 2.98

df['Na8']

# %% [markdown]
# ##### 5. $Fe_{8.0}$, $Na_{8.0}$, and $\frac{CaO}{Al_2O_3}$ are not meaningful for all values of $MgO$. Select the range of 5.0-8.5 wt.% $MgO$, for which this calculation is valid and meaningful. Plot $Fe_{8.0}$, $Na_{8.0}$, and $\frac{CaO}{Al_2O_3}$ (y-axis) versus bathymetric elevation for values of MgO in this range. I will demonstrate how to select a portion of your dataframe for which this is true.

# %%
# I select a portion of the dataframe where MgO is between 5.0 and 8.5 wt.%. 

df_lim = df[df.MgO.between(5.0, 8.5)]

df_lim

# %%
# Plot the figures here. I'll show the one for Na8.0. 

plt.figure(figsize=(6, 4)) # define figure and figure size, width vs. height
plt.scatter(df.Na8, df.Elevation, edgecolor='k', linewidth = 0.5, alpha=0.75) # scatter (x, y), edgecolor and linewidth define the scatter outlines, alpha defines transparency. 
plt.xlabel('Na8.0') # label x-axis
plt.ylabel('Axial Depth (m)') # label y-axis
plt.xlim([1, 4.5]) # set x-axis range
plt.ylim([-6000, 0]) # set y-axis range. 
plt.show()

# %% [markdown]
# ##### 6. Do MORBs display global geochemical variations beyond what should be expected from fractionation? What are the magnitude of those variations? Are they in excess of the analytical uncertainties (~0.5 wt.%)?

# %% [markdown]
# Answer here:

# %% [markdown]
# ##### 7. Are the axial traces of the world's mid-ocean ridges all at the same depth below sea level?

# %% [markdown]
# Answer here:

# %% [markdown]
# ##### 8. Formulate a hypothesis relating the elevation of a mid-ocean ridge segment and rates of melting in the underlying mantle source.

# %% [markdown]
# Answer here:

# %% [markdown]
# ##### 9. If Na is largely an incompatible element (meaning it does not want to remain in the crystal and wants to enter melt) during partial melting of the mantle, does your plot of $Na_{8.0}$ vs. elevation support your hypothesis in question 8 above?

# %% [markdown]
# Answer here:

# %% [markdown]
# ##### 12. We can now look to paired studies of geophysics and geochemistry to further understand this problem. Shear wave velocities ($V_s$) are proxies for mantle potential temperatures, representing the temperature the mantle would have at the surface if it ascended along an adiabat without undergoing melting. This was a concept proposed by [McKenzie & Bickle, 1988](https://academic.oup.com/petrology/article-abstract/29/3/625/1432023) to compare mantle temperatures at different localities. Look at the figure below from the [Dalton et al., 2014](https://www.science.org/doi/full/10.1126/science.1249466?casa_token=UxKZ9f8aOVUAAAAA%3A0MvoZnwoItZMA1wm0VhST88T-BCAX6ghGdl3h7OwWl2ZluXh2SKL1ek_409iN7HUa2btCIudbtfqXw) study. $Na_{8.0}$ is replaced by $Na_{90}$, which similarly represents a primitive basaltic liquid, but instead with $Fo$=90 mol.%. Please interpret the physical meaning of this figure. What seismic speeds and potential temperatures do you find with low sodium and high sodium content?
#
# ![daltonetal2014_vs](https://raw.githubusercontent.com/sarahshi/earthchem-teaching/main/figures/daltonetal2014_vs.png)

# %% [markdown]
# ##### 13. Finally, let's put all of this together. The [Dalton et al., 2014](https://www.science.org/doi/full/10.1126/science.1249466?casa_token=UxKZ9f8aOVUAAAAA%3A0MvoZnwoItZMA1wm0VhST88T-BCAX6ghGdl3h7OwWl2ZluXh2SKL1ek_409iN7HUa2btCIudbtfqXw) study further analyze axial depths and their relationship to potential temperature (or really, shear wave velocity, $V_s$). We plotted the MORB samples and their corresponding axial depths with PyGMT above. Do the potential temperatures pair with depth? If so, why is this? (Hint: Think about crustal thicknesses, isostasy, Archimedes' principal -- how might these explain the observable)
#
# ![daltonetal2014_ridge](https://raw.githubusercontent.com/sarahshi/earthchem-teaching/main/figures/daltonetal2014_ridge.png)

# %% [markdown]
# ### IV. Recap
#
# Write a paragraph recapping what you learned from this exercise. Do you have any suggestions for improving this exercise, as this is the first iteration of this Solid Earth module?

# %% [markdown]
# ### V. Conclusion
#
# Congratulations! You have learned some pretty important things about the global geochemical of MORBs, and what their geochemical variation may be telling us about physical conditions within the upper mantle. Of course, there are many additional and complicating factors which we haven't considered during this rather simplistic exercise. For example, how do temperature and pressure differences below the mid-ocean ridges control the melting behavior below the mid-ocean ridges? Additionally, we have totally neglected the important role of mantle plumes and hotspots--several of these features are found along the mid-ocean ridges (e.g., Iceland, the Azores, and the Galapagos), and related samples were included in your dataset that you downloaded from PetDB.
#
# While you have only grazed the surface of this complex topic, you have basically duplicated part of the work published by [Klein and Langmuir, 1987](https://agupubs.onlinelibrary.wiley.com/doi/10.1029/JB092iB08p08089) in their classic work on mid-ocean ridge geochemistry, but using a much, much larger dataset!
#
# You have successfully worked through this Jupyter notebook. Make sure you save a copy of the notebook to your Google Drive, or if you finish during the lab time, please download the notebook for submission.
